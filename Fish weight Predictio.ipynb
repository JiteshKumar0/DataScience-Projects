# %% [markdown]
# <a href="https://colab.research.google.com/github/JiteshKumar0/Jitesh-Projects/blob/main/Fish%20weight%20Predictio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
fish = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Fish.csv')

# %%
fish
# Out:
#      Category Species  Weight   Height   Width  Length1  Length2  Length3
# 0           1   Bream   242.0  11.5200  4.0200     23.2     25.4     30.0
# 1           1   Bream   290.0  12.4800  4.3056     24.0     26.3     31.2
# 2           1   Bream   340.0  12.3778  4.6961     23.9     26.5     31.1
# 3           1   Bream   363.0  12.7300  4.4555     26.3     29.0     33.5
# 4           1   Bream   430.0  12.4440  5.1340     26.5     29.0     34.0
# ..        ...     ...     ...      ...     ...      ...      ...      ...
# 154         6   Smelt    12.2   2.0904  1.3936     11.5     12.2     13.4
# 155         6   Smelt    13.4   2.4300  1.2690     11.7     12.4     13.5
# 156         6   Smelt    12.2   2.2770  1.2558     12.1     13.0     13.8
# 157         6   Smelt    19.7   2.8728  2.0672     13.2     14.3     15.2
# 158         6   Smelt    19.9   2.9322  1.8792     13.8     15.0     16.2
#
# [159 rows x 8 columns]

# %%
fish.head()
# Out:
#    Category Species  Weight   Height   Width  Length1  Length2  Length3
# 0         1   Bream   242.0  11.5200  4.0200     23.2     25.4     30.0
# 1         1   Bream   290.0  12.4800  4.3056     24.0     26.3     31.2
# 2         1   Bream   340.0  12.3778  4.6961     23.9     26.5     31.1
# 3         1   Bream   363.0  12.7300  4.4555     26.3     29.0     33.5
# 4         1   Bream   430.0  12.4440  5.1340     26.5     29.0     34.0

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  159 non-null    int64
#  1   Species   159 non-null    object
#  2   Weight    159 non-null    float64
#  3   Height    159 non-null    float64
#  4   Width     159 non-null    float64
#  5   Length1   159 non-null    float64
#  6   Length2   159 non-null    float64
#  7   Length3   159 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 10.1+ KB

# %%
fish.describe()
# Out:
#          Category       Weight      Height       Width     Length1  \
# count  159.000000   159.000000  159.000000  159.000000  159.000000
# mean     3.264151   398.326415    8.970994    4.417486   26.247170
# std      1.704249   357.978317    4.286208    1.685804    9.996441
# min      1.000000     0.000000    1.728400    1.047600    7.500000
# 25%      2.000000   120.000000    5.944800    3.385650   19.050000
# 50%      3.000000   273.000000    7.786000    4.248500   25.200000
# 75%      4.500000   650.000000   12.365900    5.584500   32.700000
# max      7.000000  1650.000000   18.957000    8.142000   59.000000
#
#           Length2     Length3
# count  159.000000  159.000000
# mean    28.415723   31.227044
# std     10.716328   11.610246
# min      8.400000    8.800000
# 25%     21.000000   23.150000
# 50%     27.300000   29.400000
# 75%     35.500000   39.650000
# max     63.400000   68.000000

# %%
fish.shape
# Out:
# (159, 8)

# %%
fish.columns
# Out:
# Index(['Category', 'Species', 'Weight', 'Height', 'Width', 'Length1',
#        'Length2', 'Length3'],
#       dtype='object')

# %%
y = fish['Weight']

# %%
X = fish[['Category','Height', 'Width', 'Length1',
       'Length2', 'Length3']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.9, random_state=2529)

# %%
X_train
# Out:
#      Category   Height   Width  Length1  Length2  Length3
# 15          1  15.4380  5.5800     29.4     32.0     37.2
# 46          5   6.5500  3.3250     21.0     22.5     25.0
# 132         4   7.2900  4.5765     35.5     38.0     40.5
# 79          3   5.6358  3.0502     17.2     19.0     20.2
# 64          2   8.3922  2.9181     17.5     19.0     21.3
# ..        ...      ...     ...      ...      ...      ...
# 72          3   2.1120  1.4080      7.5      8.4      8.8
# 143         4   9.6000  6.1440     56.0     60.0     64.0
# 60          7  12.3540  6.5250     37.3     40.0     43.5
# 50          5   7.3968  4.1272     22.1     23.5     26.8
# 96          3   7.2930  3.7230     22.0     24.0     25.5
#
# [143 rows x 6 columns]

# %%
y_train
# Out:
# 15      600.0
# 46      140.0
# 132     430.0
# 79       80.0
# 64      120.0
#         ...
# 72        5.9
# 143    1550.0
# 60     1000.0
# 50      200.0
# 96      225.0
# Name: Weight, Length: 143, dtype: float64

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((143, 6), (16, 6), (143,), (16,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -693.1733985986543

# %%
model.coef_
# Out:
# array([ 36.70652474,  49.34845433, -11.30515683,  11.13042773,
#         69.45374946, -53.78867691])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 488.95773257,  545.31798347,   76.75791749,  839.31813004,
#         164.91572117,  267.52006693,  379.87694082,  359.82677427,
#         516.97947024, -154.57251951, -126.8120252 ,  432.13676225,
#         130.86604833,  841.90041327,  555.70544976,  280.08558579])

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 110.98239006185075

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 2.236631733423555

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 18963.18354043568

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5617217649071438
